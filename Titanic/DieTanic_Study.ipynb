# %% [markdown]
# # 1. Exploratory Data Analysis (EDA)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')

import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data=pd.read_csv('train.csv')

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.isnull().sum() # checking for total null values
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# How many Survived?
f,ax=plt.subplots(1,2,figsize=(8,8))
data['Survived'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('Survived')
ax[0].set_ylabel('')
sns.countplot('Survived',data=data,ax=ax[1])
ax[1].set_title('Survived')
plt.show()

# %% [markdown]
# ## Analysing The Features

# %% [markdown]
# ### Sex-Categorical Feature

# %%
data.groupby(['Sex','Survived'])['Survived'].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data[['Sex','Survived']].groupby(['Sex']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived vs Sex')
sns.countplot('Sex',hue='Survived',data=data,ax=ax[1])
ax[1].set_title('Sex: Survived vs Dead ')
plt.show()

# %% [markdown]
# * The number of men > The number of women
# * The survial rate for a women- around 75% for a men around 18-19%
# * Looks to be a very important feature for modeling

# %% [markdown]
# ### Pclass-Oridinal Feature

# %%
pd.crosstab(data.Pclass,data.Survived,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_76cfafcf_980b_11ed_8ce5_fc7774dc0054row0_col0,#T_76cfafcf_980b_11ed_8ce5_fc7774dc0054row1_col1,#T_76cfafcf_980b_11ed_8ce5_fc7774dc0054row1_col2{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_76cfafcf_980b_11ed_8ce5_fc7774dc0054row0_col1{
#             background-color:  #cee666;
#             color:  #000000;
#         }#T_76cfafcf_980b_11ed_8ce5_fc7774dc0054row0_col2{
#             background-color:  #f4fa66;
#             color:  #000000;
#         }#T_76cfafcf_980b_11ed_8ce5_fc7774dc0054row1_col0{
#             background-color:  #f6fa66;
#             color:  #000000;
#         }#T_76cfafcf_980b_11ed_8ce5_fc7774dc0054row2_col0{
#             background-color:  #60b066;
#             color:  #000000;
#         }#T_76cfafcf_980b_11ed_8ce5_fc7774dc0054row2_col1{
#             background-color:  #dfef66;
#             color:  #000000;
#         }#T_76cfafcf_980b_11ed_8ce5_fc7774dc0054row2_col2{
# ...

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data['Pclass'].value_counts().plot.bar(color=['#CD7F32','#FFDF00','#D3D3D3'],ax=ax[0])
ax[0].set_title('Number of Passengers By Pclass')
ax[0].set_ylabel('Count')
sns.countplot('Pclass',hue='Survived',data=data,ax=ax[1])
ax[1].set_title('Pclass:Survived vs Dead')
plt.show()

# %% [markdown]
# * Passengers of Pclass 1 were a high priority in terms of rescue
# * The number of Survivale-Pclass1:63% Pclass2:48% Pclass3:25%

# %%
pd.crosstab([data.Sex,data.Survived],data.Pclass,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_7711e40b_980b_11ed_9f86_fc7774dc0054row0_col0,#T_7711e40b_980b_11ed_9f86_fc7774dc0054row0_col1,#T_7711e40b_980b_11ed_9f86_fc7774dc0054row0_col3,#T_7711e40b_980b_11ed_9f86_fc7774dc0054row3_col2{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_7711e40b_980b_11ed_9f86_fc7774dc0054row0_col2,#T_7711e40b_980b_11ed_9f86_fc7774dc0054row1_col2{
#             background-color:  #f1f866;
#             color:  #000000;
#         }#T_7711e40b_980b_11ed_9f86_fc7774dc0054row1_col0{
#             background-color:  #96cb66;
#             color:  #000000;
#         }#T_7711e40b_980b_11ed_9f86_fc7774dc0054row1_col1{
#             background-color:  #a3d166;
#             color:  #000000;
#         }#T_7711e40b_980b_11ed_9f86_fc7774dc0054row1_col3{
#             background-color:  #cfe766;
#             color:  #000000;
#         }#T_7711e40b_980b_11ed_9f86_fc7774dc0054row2_col0{
#             background-color:  #a7d366;
# ...

# %%
sns.factorplot('Pclass','Survived',hue='Sex',data=data)
plt.show()

# %% [markdown]
# * FactorPlot-making the seperation of categorical values easy
# * According to the CrossTab and the FactorPlot, the survival for Women from Pclass1 is about 95-96%
# * Pclass1 and Women were given first priority

# %% [markdown]
# ### Age-Continous Feature

# %%
print('Oldest Passenger was of:',data['Age'].max(),'Years')
print('Youngest Passenger was of:',data['Age'].min(),'Years')
print('Average Age on the ship:',data['Age'].mean(),'Years')
# Out:
# Oldest Passenger was of: 80.0 Years
# Youngest Passenger was of: 0.42 Years
# Average Age on the ship: 29.69911764705882 Years

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
sns.violinplot('Pclass','Age',hue='Survived',data=data,split=True,ax=ax[0])
ax[0].set_title('Pclass and Age vs Survived')
ax[0].set_yticks(range(0,110,10))
sns.violinplot('Sex','Age',hue='Survived',data=data,split=True,ax=ax[1])
ax[1].set_title('Sex and Age vs Survived')
ax[1].set_yticks(range(0,110,10))
plt.show()

# %% [markdown]
# * 1) The number of children increases with Pclass and the survival rate for Passengers below Age10 looks to be good irrespective of the Pclass
# * 2) Survival chances for Passenegers aged 20-50 from Pclass is high and is even better for Women
# * 3) For males, the survival chances decreases with an increase in age

# %% [markdown]
# * Replacing NaN values in the Age feature by assigning them the mean age of the dataset (using the Name feature)

# %%
data['Initial']=0
for i in data:
    data['Initial']=data.Name.str.extract('([A-Za-z]+)\.')
# extract the Salutations

# %%
pd.crosstab(data.Sex,data.Initial).style.background_gradient(cmap='summer_r')
# Checking the Initials with the Sex
# Out:
# <style  type="text/css" >
# #T_77ed1b96_980b_11ed_8c5b_fc7774dc0054row0_col0,#T_77ed1b96_980b_11ed_8c5b_fc7774dc0054row0_col1,#T_77ed1b96_980b_11ed_8c5b_fc7774dc0054row0_col3,#T_77ed1b96_980b_11ed_8c5b_fc7774dc0054row0_col4,#T_77ed1b96_980b_11ed_8c5b_fc7774dc0054row0_col5,#T_77ed1b96_980b_11ed_8c5b_fc7774dc0054row0_col7,#T_77ed1b96_980b_11ed_8c5b_fc7774dc0054row0_col8,#T_77ed1b96_980b_11ed_8c5b_fc7774dc0054row0_col12,#T_77ed1b96_980b_11ed_8c5b_fc7774dc0054row0_col15,#T_77ed1b96_980b_11ed_8c5b_fc7774dc0054row0_col16,#T_77ed1b96_980b_11ed_8c5b_fc7774dc0054row1_col2,#T_77ed1b96_980b_11ed_8c5b_fc7774dc0054row1_col6,#T_77ed1b96_980b_11ed_8c5b_fc7774dc0054row1_col9,#T_77ed1b96_980b_11ed_8c5b_fc7774dc0054row1_col10,#T_77ed1b96_980b_11ed_8c5b_fc7774dc0054row1_col11,#T_77ed1b96_980b_11ed_8c5b_fc7774dc0054row1_col13,#T_77ed1b96_980b_11ed_8c5b_fc7774dc0054row1_col14{
#             background-color:  #ffff66;
#             color:  #000000;
# ...

# %%
# Modifying misspelled Initials
data['Initial'].replace(['Mlle','Mme','Ms','Dr','Major','Lady','Countess','Jonkheer','Col','Rev','Capt','Sir','Don'],['Miss','Miss','Miss','Mr','Mr','Mrs','Mrs','Other','Other','Other','Mr','Mr','Mr'],inplace=True)

# %%
# Checking the average age by Initials
data.groupby(['Initial'])['Age'].mean()
# Out:
# Initial
# Master     4.574167
# Miss      21.860000
# Mr        32.739609
# Mrs       35.981818
# Other     45.888889
# Name: Age, dtype: float64

# %% [markdown]
# ### Filling NaN Ages

# %%
# Assigning the NaN values with the Ceil values of the mean ages
data.loc[(data.Age.isnull())&(data.Initial=='Mr'),'Age']=33
data.loc[(data.Age.isnull())&(data.Initial=='Mrs'),'Age']=36
data.loc[(data.Age.isnull())&(data.Initial=='Master'),'Age']=5
data.loc[(data.Age.isnull())&(data.Initial=='Miss'),'Age']=22
data.loc[(data.Age.isnull())&(data.Initial=='Other'),'Age']=46

# %%
data.Age.isnull().any() # Checking NaN values
# Out:
# False

# %%
f,ax=plt.subplots(1,2,figsize=(20,10))
data[data['Survived']==0].Age.plot.hist(ax=ax[0],bins=20,edgecolor='black',color='red')
ax[0].set_title('Survived=0')
x1=list(range(0,85,5))
ax[0].set_xticks(x1)
data[data['Survived']==1].Age.plot.hist(ax=ax[1],bins=20,edgecolor='black',color='green')
ax[1].set_title('Survived=1')
ax[1].set_xticks(x1)
plt.show()

# %% [markdown]
# * age<5 were saved in large numbers(The Women and Child First Policy)
# * The oldest Passenger was saved(80 years)
# * Maximum number of deaths were in the age group of 30-40

# %%
plt.figsize=(18,8)
sns.factorplot('Pclass','Survived',col='Initial',data=data)
plt.show()

# %% [markdown]
# ### Embarked-Categorical Value

# %%
pd.crosstab([data.Embarked,data.Pclass],[data.Sex,data.Survived],margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_7907b37d_980b_11ed_909d_fc7774dc0054row0_col0,#T_7907b37d_980b_11ed_909d_fc7774dc0054row1_col2{
#             background-color:  #fcfe66;
#             color:  #000000;
#         }#T_7907b37d_980b_11ed_909d_fc7774dc0054row0_col1{
#             background-color:  #d2e866;
#             color:  #000000;
#         }#T_7907b37d_980b_11ed_909d_fc7774dc0054row0_col2{
#             background-color:  #f2f866;
#             color:  #000000;
#         }#T_7907b37d_980b_11ed_909d_fc7774dc0054row0_col3{
#             background-color:  #d8ec66;
#             color:  #000000;
#         }#T_7907b37d_980b_11ed_909d_fc7774dc0054row0_col4,#T_7907b37d_980b_11ed_909d_fc7774dc0054row2_col3{
#             background-color:  #e8f466;
#             color:  #000000;
# ...

# %% [markdown]
# #### Chances for Survival by Port Of Embarkation

# %%
sns.factorplot('Embarked','Survived',data=data)
fig=plt.gcf()
fig.set_size_inches(5,3)
plt.show()

# %% [markdown]
# * The chances for survival for Port C is highest around 0.55 while it is lowest for S

# %%
f,ax=plt.subplots(2,2,figsize=(20,15))
sns.countplot('Embarked',data=data,ax=ax[0,0])
ax[0,0].set_title('No. Of Passengers Boarded')
sns.countplot('Embarked',hue='Sex',data=data,ax=ax[0,1])
ax[0,1].set_title('Male-Female Split for Embarked')
sns.countplot('Embarked',hue='Survived',data=data,ax=ax[1,0])
ax[1,0].set_title('Embarked vs Survived')
sns.countplot('Embarked',hue='Pclass',data=data,ax=ax[1,1])
ax[1,1].set_title('Embarked vs Pclass')
plt.subplots_adjust(wspace=0.2,hspace=0.5)
plt.show()

# %% [markdown]
# * Maximum passenegers boarded from S, Majority of them being from Pclass3
# * The passengers from C look to be lucky (The reason for this maybe the rescue of all the Pclass1 and Pclass2 Passengers)
# * The Embark S-where majority of the rich people boarded
# * The Embark S-The chances for survival is low (Many passengers from Pclass3 around 81% didn't survive)
# * Port Q had almost 95% of the passengers were from Pclass3.

# %%
sns.factorplot('Pclass','Survived',hue='Sex',col='Embarked',data=data)
plt.show()

# %% [markdown]
# * The survival chances are almost 1 for women for Pclass1 and Pclass2 irrespective of the Pclass
# * Port S looks to be very unlucky for Pclass 3
# * Port Q looks to be unlukiest for Men

# %% [markdown]
# #### Filling Embarked NaN

# %%
# Replcing NaN with S because the maximum passengers boarded from Port S
data['Embarked'].fillna('S',inplace=True)

# %%
data.Embarked.isnull().any()
# Out:
# False

# %% [markdown]
# ## SibSip-Discrete Feature
# * Sibling=brother,sister,stepbrother,stepsister
# * Spouse=husband,wife

# %%
pd.crosstab([data.SibSp],data.Survived).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_7a7173fb_980b_11ed_a4fe_fc7774dc0054row0_col0,#T_7a7173fb_980b_11ed_a4fe_fc7774dc0054row0_col1{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }#T_7a7173fb_980b_11ed_a4fe_fc7774dc0054row1_col0{
#             background-color:  #c4e266;
#             color:  #000000;
#         }#T_7a7173fb_980b_11ed_a4fe_fc7774dc0054row1_col1{
#             background-color:  #77bb66;
#             color:  #000000;
#         }#T_7a7173fb_980b_11ed_a4fe_fc7774dc0054row2_col0,#T_7a7173fb_980b_11ed_a4fe_fc7774dc0054row4_col0{
#             background-color:  #f9fc66;
#             color:  #000000;
#         }#T_7a7173fb_980b_11ed_a4fe_fc7774dc0054row2_col1{
#             background-color:  #f0f866;
#             color:  #000000;
#         }#T_7a7173fb_980b_11ed_a4fe_fc7774dc0054row3_col0,#T_7a7173fb_980b_11ed_a4fe_fc7774dc0054row3_col1{
#             background-color:  #fbfd66;
#             color:  #000000;
# ...

# %%
f,ax=plt.subplots(1,2,figsize=(20,8))
sns.barplot('SibSp','Survived',data=data,ax=ax[0])
ax[0].set_title('SibSp vs Survived')
sns.factorplot('SibSp','Survived',data=data,ax=ax[1])
ax[1].set_title('SibSp vs Survived')
plt.show()

# %%
pd.crosstab(data.SibSp,data.Pclass).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_7b2f39a1_980b_11ed_8692_fc7774dc0054row0_col0,#T_7b2f39a1_980b_11ed_8692_fc7774dc0054row0_col1,#T_7b2f39a1_980b_11ed_8692_fc7774dc0054row0_col2{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }#T_7b2f39a1_980b_11ed_8692_fc7774dc0054row1_col0{
#             background-color:  #7bbd66;
#             color:  #000000;
#         }#T_7b2f39a1_980b_11ed_8692_fc7774dc0054row1_col1{
#             background-color:  #8ac466;
#             color:  #000000;
#         }#T_7b2f39a1_980b_11ed_8692_fc7774dc0054row1_col2{
#             background-color:  #c6e266;
#             color:  #000000;
#         }#T_7b2f39a1_980b_11ed_8692_fc7774dc0054row2_col0,#T_7b2f39a1_980b_11ed_8692_fc7774dc0054row4_col2{
#             background-color:  #f6fa66;
#             color:  #000000;
#         }#T_7b2f39a1_980b_11ed_8692_fc7774dc0054row2_col1{
#             background-color:  #eef666;
#             color:  #000000;
# ...

# %% [markdown]
# * If a passengers is alone onboard with no siblings, has 34.5% survival rate
# * The survival for families with 5-8 members is 0%
# * why? Because of Pclass: Person with SibSp>3 were all in Pclass 3, It is imminent that all the large families in Pclass(>3) died.

# %% [markdown]
# ## Parch

# %%
pd.crosstab(data.Parch,data.Pclass).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_7b359d9c_980b_11ed_b0af_fc7774dc0054row0_col0,#T_7b359d9c_980b_11ed_b0af_fc7774dc0054row0_col1,#T_7b359d9c_980b_11ed_b0af_fc7774dc0054row0_col2{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }#T_7b359d9c_980b_11ed_b0af_fc7774dc0054row1_col0{
#             background-color:  #cfe766;
#             color:  #000000;
#         }#T_7b359d9c_980b_11ed_b0af_fc7774dc0054row1_col1{
#             background-color:  #c2e066;
#             color:  #000000;
#         }#T_7b359d9c_980b_11ed_b0af_fc7774dc0054row1_col2{
#             background-color:  #dbed66;
#             color:  #000000;
#         }#T_7b359d9c_980b_11ed_b0af_fc7774dc0054row2_col0{
#             background-color:  #dfef66;
#             color:  #000000;
#         }#T_7b359d9c_980b_11ed_b0af_fc7774dc0054row2_col1{
#             background-color:  #e1f066;
#             color:  #000000;
#         }#T_7b359d9c_980b_11ed_b0af_fc7774dc0054row2_col2{
# ...

# %%
f,ax=plt.subplots(1,2,figsize=(20,8))
sns.barplot('Parch','Survived',data=data,ax=ax[0])
ax[0].set_title('Parch vs Survived')
sns.factorplot('Parch','Survived',data=data,ax=ax[1])
ax[1].set_title('Parch vs Survived')
plt.show()

# %% [markdown]
# * Passengers with their parents onboard have greater chance of survival
# * However, it reduces as the number goes up
# * The chances of survival is good for somebody who has 1-3 parents on the ship
# * Being alone also proves to be fatal.
# * The chances for survival decreases when somebody has >4 parents on the ship

# %% [markdown]
# ## Fare-Continous Feature

# %%
print('Highest Fare was:',data['Fare'].max())
print('Lowest Fare was:',data['Fare'].min())
print('Aveage Fare was:',data['Fare'].mean())
# Out:
# Highest Fare was: 512.3292
# Lowest Fare was: 0.0
# Aveage Fare was: 32.2042079685746

# %%
f,ax=plt.subplots(1,3,figsize=(20,8))
sns.distplot(data[data['Pclass']==1].Fare,ax=ax[0])
ax[0].set_title('Fares in Pclass 1')
sns.distplot(data[data['Pclass']==2].Fare,ax=ax[1])
ax[1].set_title('Fares in Pclass 2')
sns.distplot(data[data['Pclass']==3].Fare,ax=ax[2])
ax[2].set_title('Fares in Pclass 3')
plt.show()

# %% [markdown]
# ## Observations in a Nutshell for all features

# %% [markdown]
# * Sex: The chance of survival for women is high as compared to men.
#
# * Pclass:There is a visible trend that being a 1st class passenger gives you better chances of survival. The survival rate for Pclass3 is very low. For women, the chance of survival from Pclass1 is almost 1 and is high too for those from Pclass2. Money Wins!!!.
#
# * Age: Children less than 5-10 years do have a high chance of survival. Passengers between age group 15 to 35 died a lot.
#
# * Embarked: This is a very interesting feature. The chances of survival at C looks to be better than even though the majority of Pclass1 passengers got up at S. Passengers at Q were all from Pclass3.
#
# * Parch+SibSp: Having 1-2 siblings,spouse on board or 1-3 Parents shows a greater chance of probablity rather than being alone or having a large family travelling with you.

# %% [markdown]
# ## Correlation Between The Features

# %%
sns.heatmap(data.corr(),annot=True,cmap='RdYlGn',linewidths=0.2) #data.corr()-->correlation matrix
fig=plt.gcf()
fig.set_size_inches(10,8)
plt.show()

# %% [markdown]
# # 2. Feature Engineering and Data Cleaning

# %% [markdown]
# * It is not necessary that all the features will be important
# * There maybe be many redundant fetures which should be eliminated.
# * Also getting or adding features by observing or extracting information from other features.

# %% [markdown]
# ## Age_band

# %% [markdown]
# * Age(A continuous feature)-There is a problem with Continous Variables in Machine Learning Models
#
# * Need to convert continous values into categorical values by either Binning or Normalisation.

# %%
data['Age_band']=0
data.loc[data['Age']<=16,'Age_band']=0
data.loc[(data['Age']>16)&(data['Age']<=32),'Age_band']=1
data.loc[(data['Age']>32)&(data['Age']<=48),'Age_band']=2
data.loc[(data['Age']>48)&(data['Age']<=64),'Age_band']=3
data.loc[data['Age']>64,'Age_band']=4
data.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked Initial  Age_band
# 0      0  A/5 21171   7.2500   NaN        S      Mr         1
# 1      0   PC 17599  71.2833   C85        C     Mrs         2

# %%
data['Age_band'].value_counts().to_frame().style.background_gradient(cmap='summer')
# checking the number of passenegers in each band
# Out:
# <style  type="text/css" >
# #T_7ccb988d_980b_11ed_a605_fc7774dc0054row0_col0{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_7ccb988d_980b_11ed_a605_fc7774dc0054row1_col0{
#             background-color:  #d8ec66;
#             color:  #000000;
#         }#T_7ccb988d_980b_11ed_a605_fc7774dc0054row2_col0{
#             background-color:  #40a066;
#             color:  #000000;
#         }#T_7ccb988d_980b_11ed_a605_fc7774dc0054row3_col0{
#             background-color:  #289366;
#             color:  #000000;
#         }#T_7ccb988d_980b_11ed_a605_fc7774dc0054row4_col0{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_7ccb988d_980b_11ed_a605_fc7774dc0054" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Age_band</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
sns.factorplot('Age_band','Survived',data=data,col='Pclass')

# %% [markdown]
# * The survival rate decreases as the age increase irrespective of the Pclass

# %% [markdown]
# ## Family_size and Alone

# %%
data['Family_Size']=0
data['Family_Size']=data['Parch']+data['SibSp'] #family size
data['Alone']=0
data.loc[data.Family_Size==0,'Alone']=1 # Alone

f,ax=plt.subplots(1,2,figsize=(18,6))
sns.factorplot('Family_Size','Survived',data=data,ax=ax[0])
ax[0].set_title('Family_Size vs Survived')
sns.factorplot('Alone','Survived',data=data,ax=ax[1])
ax[1].set_title('Alone vs Survived')

plt.show()

# %% [markdown]
# * Alone or Family_Size=0, Family_Size>4: The chances for survival is low

# %%
sns.factorplot('Alone','Survived',data=data,hue='Sex',col='Pclass')
plt.show()

# %% [markdown]
# * Being alone is harmful irrespective of Sex or Pclass except for Pclass3

# %% [markdown]
# ## Fare_Range

# %%
data['Fare_Range']=pd.qcut(data['Fare'],4)
data.groupby(['Fare_Range'])['Survived'].mean().to_frame().style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_7ec08927_980b_11ed_b9df_fc7774dc0054row0_col0{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_7ec08927_980b_11ed_b9df_fc7774dc0054row1_col0{
#             background-color:  #b9dc66;
#             color:  #000000;
#         }#T_7ec08927_980b_11ed_b9df_fc7774dc0054row2_col0{
#             background-color:  #54aa66;
#             color:  #000000;
#         }#T_7ec08927_980b_11ed_b9df_fc7774dc0054row3_col0{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_7ec08927_980b_11ed_b9df_fc7774dc0054" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Survived</th>    </tr>    <tr>        <th class="index_name level0" >Fare_Range</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
# ...

# %% [markdown]
# * fare_range increases, the chances of survival increases

# %%
data['Fare_cat']=0
data.loc[data['Fare']<=7.91,'Fare_cat']=0
data.loc[(data['Fare']>7.91)&(data['Fare']<=14.454),'Fare_cat']=1
data.loc[(data['Fare']>14.454)&(data['Fare']<=31),'Fare_cat']=2
data.loc[(data['Fare']>31)&(data['Fare']<=513),'Fare_cat']=3

# %%
sns.factorplot('Fare_cat','Survived',data=data,hue='Sex')
plt.show()

# %% [markdown]
# * This feature may become an important feature during modelling along with the Sex

# %% [markdown]
# ## Converting String Values into Numeric

# %% [markdown]
# * Can't pass strings to a machine learning model

# %%
data['Sex'].replace(['male','female'],[0,1],inplace=True)
data['Embarked'].replace(['S','C','Q'],[0,1,2],inplace=True)
data['Initial'].replace(['Mr','Mrs','Miss','Master','Other'],[0,1,2,3,4],inplace=True)

# %% [markdown]
# ### Dropping UnNeeded Features
#
# * Name--> We don't need name feature as it cannot be converted into any categorical value.
#
# * Age--> We have the Age_band feature, so no need of this.
#
# * Ticket--> It is any random string that cannot be categorised.
#
# * Fare--> We have the Fare_cat feature, so unneeded
#
# * Cabin--> A lot of NaN values and also many passengers have multiple cabins. So this is a useless feature.
#
# * Fare_Range--> We have the fare_cat feature.
#
# * PassengerId--> Cannot be categorised.

# %%
data.drop(['Name','Age','Ticket','Fare','Cabin','Fare_Range','PassengerId'],axis=1,inplace=True)
sns.heatmap(data.corr(),annot=True,cmap='RdYlGn',linewidths=0.2,annot_kws={'size':20})
fig=plt.gcf()
fig.set_size_inches(18,15)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show()

# %% [markdown]
# * Positvely related features-SibSp and Family_Size, Parch and Family_Size
# * Negatively related features-Alond and Family_Size
